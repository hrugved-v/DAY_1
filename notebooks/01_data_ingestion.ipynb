# %%
import pandas as pd
import os

# %%
folder = "C:\\Users\\Hrugved\\OneDrive\\Desktop\\DAY1\\data\\raw"


for file in sorted(os.listdir(folder)):
    
    if file.endswith(".csv"):
        
        df = pd.read_csv(os.path.join(folder,file))

        print("="*70)
        print(file)

        print("\nShape:")
        print(df.shape)

        print("\nDtypes:")
        print(df.dtypes)

        print("\nHead:")
        display(df.head())
# Out:
# ...
# 01_fund_master.csv
#
# Shape:
# (40, 15)
#
# Dtypes:
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object
#
# Head:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
for file in sorted(os.listdir(folder)):
    
    if file.endswith(".csv"):
        
        df = pd.read_csv(os.path.join(folder,file))

        print(file)

        print("Missing Values")
        print(df.isnull().sum())

        print("\nDuplicates")
        print(df.duplicated().sum())
# Out:
# 01_fund_master.csv
# Missing Values
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# Duplicates
# 0
# 02_nav_history.csv
# Missing Values
# amfi_code    0
# date         0
# nav          0
# dtype: int64
#
# Duplicates
# 0
# 03_aum_by_fund_house.csv
# Missing Values
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64
#
# Duplicates
# 0
# 04_monthly_sip_inflows.csv
# Missing Values
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# ...

# %%
sip = pd.read_csv("C:\\Users\\Hrugved\\OneDrive\\Desktop\\DAY1\\data\\raw\\04_monthly_sip_inflows.csv")
sip[sip["yoy_growth_pct"].isnull()]
# Out:
#       month  sip_inflow_crore  active_sip_accounts_crore  \
# 0   2022-01             11517                       4.91
# 1   2022-02             11438                       4.93
# 2   2022-03             12328                       5.09
# 3   2022-04             11863                       5.48
# 4   2022-05             12286                       5.55
# 5   2022-06             12276                       5.60
# 6   2022-07             12140                       5.65
# 7   2022-08             12694                       5.71
# 8   2022-09             12976                       5.80
# 9   2022-10             13040                       5.93
# 10  2022-11             13306                       6.00
# 11  2022-12             13573                       6.05
#
#     new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                    9.10                4.80             NaN
# 1                    8.20                4.85             NaN
# ...

# %% [markdown]
# ### found missing values in 4th excel sheet ie in monthly sip inflows csv, however the missing values were in yoy_growth_percentage the early rows were NULL as earlier entries dont have previous months entries so pct cant be calculated therefore the dataset provided is neat.
# ### now moving onto exploring fund master csv

# %%
fund_master = pd.read_csv("C:\\Users\\Hrugved\\OneDrive\\Desktop\\DAY1\\data\\raw\\01_fund_master.csv")
fund_master.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 9.9 KB

# %%
fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
print("Unique Fund Houses:", fund_master["fund_house"].nunique())
print("Unique Categories:", fund_master["category"].nunique())
print("Unique Sub Categories:", fund_master["sub_category"].nunique())
print("Unique Risk Categories:", fund_master["risk_category"].nunique())
# Out:
# Unique Fund Houses: 10
# Unique Categories: 2
# Unique Sub Categories: 12
# Unique Risk Categories: 5

# %% [markdown]
# ### AMFI code is a ID of a mutual fund scheme. It acts as a reference for linking different mutual funds information across databases.

# %%
nav_history = pd.read_csv("data/raw/02_nav_history.csv")

# %%
nav_history.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  str
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 1.5 MB

# %%
nav_history.columns.tolist()
# Out:
# ['amfi_code', 'date', 'nav']

# %%
master_codes = set(fund_master["amfi_code"])
nav_codes = set(nav_history["amfi_code"])
missing_codes = master_codes - nav_codes
print("AMFI codes in fund_master but not in nav_history:", missing_codes)
# Out:
# AMFI codes in fund_master but not in nav_history: set()

# %% [markdown]
# ### All AMFI codes in nav history were found hence there are no missing nav, hence there is a strong consistency in both the datasets ie 01 & 02

# %% [markdown]
# ### DAY 1 DATASET QUALITY SUMMARY

# %% [markdown]
# All the datasets were succesfully added, 10 datasets were in total. After thorough exploration and analysis it was found there were no duplicate records, only 12 missing values in SIP INFLOW dataset which were further recognised and the issue was solved in the above comments/code. These missing values were in the yoy_growth pct that could not be calculated as the formula requires previous year data which wasnt provided as they were earlier records. Furhtermore all AMFI code were validated by comparing codes in 02 to 01 no missing amfi codes were found. In conclusion DAY 1 task was successfully completed.
